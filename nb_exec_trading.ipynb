# %% [markdown]
# # Phase 4: Trading Strategy implementation

# %% [markdown]
# **Phase inputs**
# - `stock_prices.csv`: DataFrame of asset prices, cleaned
# - `clusters.csv`: DataFrame of clusters
#
# **Phase outputs**
# - No data outputs, only graphical and numerical results

# %%
from main_trading import main_4

main_4(window_clustering= 300,
       window_lookback= 50,
       lambda_in = 3,
       lambda_out = 0.5,
       lambda_emergency = 3,
       patience_max = 120,
       use_SUBDATA = True,
       nb_pairs_cap=10,  # Use -1 to use all pairs
       plot_pairs_lifetimes=False,
       display_figures=True)
# Out:
# ======================================================================
# ENTERING PHASE 4: TRADING STRATEGY IMPELMENTATION
# ======================================================================
#
# 4.1 Loading phase inputs...
#   Loading + structuring 'stock_prices.csv'...
#   Loading + structuring 'stock_returns.csv'...
#   Loading + structuring 'stock_spreads.csv'...
# {'ABT': 0, 'AEP': 1, 'ALL': 2, 'APA': 3, 'AVP': 4, 'AXP': 5, 'BA': 6, 'BAC': 7, 'BAX': 8, 'BHI': 9, 'BK': 10, 'BMY': 11, 'C': 12, 'CAT': 13, 'CL': 14, 'COF': 15, 'COP': 16, 'CVS': 17, 'CVX': 18, 'DD': 19, 'DIS': 20, 'DOW': 21, 'EMC': 22, 'EMR': 23, 'ETR': 24, 'EXC': 25, 'F': 26, 'FCX': 27, 'FDX': 28, 'GD': 29, 'GE': 30, 'GS': 31, 'HAL': 32, 'HD': 33, 'HNZ': 34, 'HON': 35, 'HPQ': 36, 'IBM': 37, 'JNJ': 38, 'JPM': 39, 'KFT': 40, 'KO': 41, 'LMT': 42, 'LOW': 43, 'MCD': 44, 'MDT': 45, 'MET': 46, 'MMM': 47, 'MO': 48, 'MON': 49, 'MRK': 50, 'NKE': 51, 'NSC': 52, 'OXY': 53, 'PEP': 54, 'PFE': 55, 'PG': 56, 'RTN': 57, 'S': 58, 'SLB': 59, 'SO': 60, 'T': 61, 'TGT': 62, 'TWX': 63, 'TXN': 64, 'UNH': 65, 'UNP': 66, 'UPS': 67, 'USB': 68, 'UTX': 69, 'VZ': 70, 'WAG': 71, 'WFC': 72, 'WMB': 73, 'WMT': 74, 'WY': 75, 'XOM': 76, 'XRX': 77}
# 4.2 Building DATA master dictionary...
#   Argument 'use_SUBDATA' = True -> Using restricted range (approx. 3 weeks) only
#   --> gives 6524 timestamps.
#   Succesfully built DATA dictionary.
#   (Sanity check) Plotting cumulative returns of 5 random assets:
# 4.3 Implementing rolling clustering approach...
#   Clustering will be recalculated every 300 timestamps
#   Successfully initialized empty positions table, shape:(6524, 79)
#   Total timestamps: 6524, Number of rolling windows: 21
#
#   === Rolling Window 1/21 ===
#   Clustering period: t=0 to t=299
#   Trading period: t=300 to t=599
#   Starting Louvain clustering...
#   Louvain clustering completed.
#   Generated 3 clusters for this window
#   Constructed 636 pairs, evaluating 10 pairs
#     Evaluating pair 5/10: AEP-BAX
#     Evaluating pair 10/10: AEP-GD
#   Forcing exit of all positions at end of window (t=599)
#
#   === Rolling Window 2/21 ===
#   Clustering period: t=300 to t=599
#   Trading period: t=600 to t=899
#   Starting Louvain clustering...
#   Louvain clustering completed.
#   Generated 4 clusters for this window
#   Constructed 678 pairs, evaluating 10 pairs
#     Evaluating pair 5/10: ABT-BK
#     Evaluating pair 10/10: ABT-KO
#   Forcing exit of all positions at end of window (t=899)
#
#   === Rolling Window 3/21 ===
#   Clustering period: t=600 to t=899
#   Trading period: t=900 to t=1199
#   Starting Louvain clustering...
#   Louvain clustering completed.
#   Generated 4 clusters for this window
#   Constructed 683 pairs, evaluating 10 pairs
#     Evaluating pair 5/10: AVP-DD
#     Evaluating pair 10/10: AVP-FDX
#   Forcing exit of all positions at end of window (t=1199)
#
#   === Rolling Window 4/21 ===
#   Clustering period: t=900 to t=1199
#   Trading period: t=1200 to t=1499
#   Starting Louvain clustering...
#   Louvain clustering completed.
#   Generated 3 clusters for this window
#   Constructed 1486 pairs, evaluating 10 pairs
#     Evaluating pair 5/10: APA-DD
#     Evaluating pair 10/10: APA-F
#   Forcing exit of all positions at end of window (t=1499)
#
#   === Rolling Window 5/21 ===
#   Clustering period: t=1200 to t=1499
#   Trading period: t=1500 to t=1799
#   Starting Louvain clustering...
#   Louvain clustering completed.
#   Generated 3 clusters for this window
#   Constructed 583 pairs, evaluating 10 pairs
#     Evaluating pair 5/10: ALL-BK
#     Evaluating pair 10/10: ALL-EMR
#   Forcing exit of all positions at end of window (t=1799)
#
#   === Rolling Window 6/21 ===
#   Clustering period: t=1500 to t=1799
#   Trading period: t=1800 to t=2099
#   Starting Louvain clustering...
#   Louvain clustering completed.
#   Generated 4 clusters for this window
#   Constructed 681 pairs, evaluating 10 pairs
#     Evaluating pair 5/10: ABT-COF
#     Evaluating pair 10/10: ABT-MET
#   Forcing exit of all positions at end of window (t=2099)
#
#   === Rolling Window 7/21 ===
#   Clustering period: t=1800 to t=2099
#   Trading period: t=2100 to t=2399
#   Starting Louvain clustering...
#   Louvain clustering completed.
#   Generated 4 clusters for this window
#   Constructed 695 pairs, evaluating 10 pairs
#     Evaluating pair 5/10: ABT-DIS
#     Evaluating pair 10/10: ABT-MMM
#   Forcing exit of all positions at end of window (t=2399)
#
#   === Rolling Window 8/21 ===
#   Clustering period: t=2100 to t=2399
#   Trading period: t=2400 to t=2699
#   Starting Louvain clustering...
#   Louvain clustering completed.
#   Generated 3 clusters for this window
#   Constructed 496 pairs, evaluating 10 pairs
#     Evaluating pair 5/10: APA-CVS
#     Evaluating pair 10/10: APA-FCX
#   Forcing exit of all positions at end of window (t=2699)
#
#   === Rolling Window 9/21 ===
#   Clustering period: t=2400 to t=2699
#   Trading period: t=2700 to t=2999
#   Starting Louvain clustering...
#   Louvain clustering completed.
#   Generated 3 clusters for this window
#   Constructed 288 pairs, evaluating 10 pairs
#     Evaluating pair 5/10: AVP-DOW
#     Evaluating pair 10/10: AVP-LMT
#   Forcing exit of all positions at end of window (t=2999)
#
#   === Rolling Window 10/21 ===
#   Clustering period: t=2700 to t=2999
#   Trading period: t=3000 to t=3299
#   Starting Louvain clustering...
#   Louvain clustering completed.
#   Generated 3 clusters for this window
#   Constructed 837 pairs, evaluating 10 pairs
#     Evaluating pair 5/10: ALL-BK
#     Evaluating pair 10/10: ALL-EMC
#   Forcing exit of all positions at end of window (t=3299)
#
#   === Rolling Window 11/21 ===
#   Clustering period: t=3000 to t=3299
#   Trading period: t=3300 to t=3599
#   Starting Louvain clustering...
#   Louvain clustering completed.
#   Generated 4 clusters for this window
#   Constructed 445 pairs, evaluating 10 pairs
#     Evaluating pair 5/10: AEP-IBM
#     Evaluating pair 10/10: AEP-MET
#   Forcing exit of all positions at end of window (t=3599)
#
#   === Rolling Window 12/21 ===
#   Clustering period: t=3300 to t=3599
#   Trading period: t=3600 to t=3899
#   Starting Louvain clustering...
#   Louvain clustering completed.
#   Generated 3 clusters for this window
#   Constructed 981 pairs, evaluating 10 pairs
#     Evaluating pair 5/10: APA-COP
#     Evaluating pair 10/10: APA-EMC
#   Forcing exit of all positions at end of window (t=3899)
#
#   === Rolling Window 13/21 ===
#   Clustering period: t=3600 to t=3899
#   Trading period: t=3900 to t=4199
#   Starting Louvain clustering...
#   Louvain clustering completed.
#   Generated 4 clusters for this window
#   Constructed 431 pairs, evaluating 10 pairs
#     Evaluating pair 5/10: AEP-FCX
#     Evaluating pair 10/10: AEP-IBM
#   Forcing exit of all positions at end of window (t=4199)
#
#   === Rolling Window 14/21 ===
#   Clustering period: t=3900 to t=4199
#   Trading period: t=4200 to t=4499
#   Starting Louvain clustering...
#   Louvain clustering completed.
#   Generated 4 clusters for this window
#   Constructed 751 pairs, evaluating 10 pairs
#     Evaluating pair 5/10: ABT-EXC
#     Evaluating pair 10/10: ABT-LOW
#   Forcing exit of all positions at end of window (t=4499)
#
#   === Rolling Window 15/21 ===
#   Clustering period: t=4200 to t=4499
#   Trading period: t=4500 to t=4799
#   Starting Louvain clustering...
#   Louvain clustering completed.
#   Generated 4 clusters for this window
#   Constructed 518 pairs, evaluating 10 pairs
#     Evaluating pair 5/10: ALL-CL
#     Evaluating pair 10/10: ALL-GE
#   Forcing exit of all positions at end of window (t=4799)
#
#   === Rolling Window 16/21 ===
#   Clustering period: t=4500 to t=4799
#   Trading period: t=4800 to t=5099
#   Starting Louvain clustering...
#   Louvain clustering completed.
#   Generated 3 clusters for this window
#   Constructed 555 pairs, evaluating 10 pairs
#     Evaluating pair 5/10: APA-DIS
#     Evaluating pair 10/10: APA-HON
#   Forcing exit of all positions at end of window (t=5099)
#
#   === Rolling Window 17/21 ===
#   Clustering period: t=4800 to t=5099
#   Trading period: t=5100 to t=5399
#   Starting Louvain clustering...
#   Louvain clustering completed.
#   Generated 6 clusters for this window
#   Constructed 475 pairs, evaluating 10 pairs
#     Evaluating pair 5/10: AEP-EMC
#     Evaluating pair 10/10: AEP-LMT
#   Forcing exit of all positions at end of window (t=5399)
#
#   === Rolling Window 18/21 ===
#   Clustering period: t=5100 to t=5399
#   Trading period: t=5400 to t=5699
#   Starting Louvain clustering...
#   Louvain clustering completed.
#   Generated 3 clusters for this window
#   Constructed 993 pairs, evaluating 10 pairs
#     Evaluating pair 5/10: AEP-COF
#     Evaluating pair 10/10: AEP-DOW
#   Forcing exit of all positions at end of window (t=5699)
#
#   === Rolling Window 19/21 ===
#   Clustering period: t=5400 to t=5699
#   Trading period: t=5700 to t=5999
#   Starting Louvain clustering...
#   Louvain clustering completed.
#   Generated 3 clusters for this window
#   Constructed 686 pairs, evaluating 10 pairs
#     Evaluating pair 5/10: APA-COP
#     Evaluating pair 10/10: APA-EMR
#   Forcing exit of all positions at end of window (t=5999)
#
#   === Rolling Window 20/21 ===
#   Clustering period: t=5700 to t=5999
#   Trading period: t=6000 to t=6299
#   Starting Louvain clustering...
#   Louvain clustering completed.
#   Generated 4 clusters for this window
#   Constructed 547 pairs, evaluating 10 pairs
#     Evaluating pair 5/10: ABT-CVS
#     Evaluating pair 10/10: ABT-GD
#   Forcing exit of all positions at end of window (t=6299)
#
#   === Rolling Window 21/21 ===
#   Clustering period: t=6000 to t=6299
#   Trading period: t=6300 to t=6523
#   Starting Louvain clustering...
#   Louvain clustering completed.
#   Generated 3 clusters for this window
#   Constructed 561 pairs, evaluating 10 pairs
#     Evaluating pair 5/10: AEP-DOW
#     Evaluating pair 10/10: AEP-HD
#   Forcing exit of all positions at end of window (t=6523)
#
# 4.4 All rolling windows completed.
#   Final positions array shape: (6524, 79) (columns allocated for 78 assets, +1 for row-wise sum).
# 4.5 Computing PNL series...
# ======================================================================
# PHASE 4 CORRECTLY TERMINATED
# ======================================================================
