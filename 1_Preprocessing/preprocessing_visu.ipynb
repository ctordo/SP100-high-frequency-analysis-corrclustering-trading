# %%
# Import the main function
from main_polars import main_1
import polars as pl

# %%
panel = main_1()
# Out:
# Initializing data preprocessor...
#
# Step 1: Processing/Loading cleaned assets...
# ======================================================================
# PROCESSING 85 ASSETS
# Date filter: 2008-09-01 to 2008-12-31
# ======================================================================
# Files already cleaned: 85
# Files to process: 0
# ======================================================================
#
# Timestamp file already exists, loading it...
#
# ======================================================================
#
# Assets to skip due to incomplete data coverage: 7
# Assets: ['AA.N', 'DVN.N', 'MA.N', 'MS.N', 'NOV.N', 'PM.N', 'V.N']
#
# ======================================================================
#
# Missing data report already exists, skipping analysis...
#
# ======================================================================
#
# [1/85] Loading MDT.N... (already cleaned)
#   Loaded: 3,322,742 rows
#
# [2/85] Loading KFT.N... (already cleaned)
#   Loaded: 3,858,623 rows
#
# [3/85] Loading CL.N... (already cleaned)
#   Loaded: 3,114,122 rows
#
# [4/85] Loading EMR.N... (already cleaned)
#   Loaded: 3,256,258 rows
#
# [5/85] Loading VZ.N... (already cleaned)
#   Loaded: 4,534,184 rows
#
# [6/85] Loading CVX.N... (already cleaned)
#   Loaded: 6,128,782 rows
#
# [7/85] Loading IBM.N... (already cleaned)
#   Loaded: 4,427,542 rows
#
# [8/85] Loading TWX.N... (already cleaned)
#   Loaded: 4,280,817 rows
#
# [9/85] Loading DOW.N... (already cleaned)
#   Loaded: 4,100,149 rows
#
# [10/85] Loading BHI.N... (already cleaned)
#   Loaded: 3,894,528 rows
#
# [11/85] Loading HAL.N... (already cleaned)
#   Loaded: 4,305,361 rows
#
# [12/85] Loading ALL.N... (already cleaned)
#   Loaded: 3,755,047 rows
#
# [13/85] Loading XRX.N... (already cleaned)
#   Loaded: 2,562,659 rows
#
# [14/85] Loading GE.N... (already cleaned)
#   Loaded: 5,995,309 rows
#
# [15/85] Loading PG.N... (already cleaned)
#   Loaded: 4,107,046 rows
#
# [16/85] Loading AEP.N... (already cleaned)
#   Loaded: 3,637,410 rows
#
# [17/85] Loading WAG.N... (already cleaned)
#   Loaded: 3,264,208 rows
#
# [18/85] Loading UNH.N... (already cleaned)
#   Loaded: 3,025,645 rows
#
# [19/85] Loading PFE.N... (already cleaned)
#   Loaded: 4,043,741 rows
#
# [20/85] Loading UNP.N... (already cleaned)
#   Loaded: 4,263,070 rows
#
# [21/85] Loading CVS.N... (already cleaned)
#   Loaded: 3,713,499 rows
#
# [22/85] Loading MO.N... (already cleaned)
#   Loaded: 3,538,621 rows
#
# [23/85] Loading SO.N... (already cleaned)
#   Loaded: 2,737,008 rows
#
# [24/85] Loading BAX.N... (already cleaned)
#   Loaded: 3,534,453 rows
#
# [25/85] Loading AVP.N... (already cleaned)
#   Loaded: 2,210,415 rows
#
# [26/85] Loading HD.N... (already cleaned)
#   Loaded: 4,064,567 rows
#
# [27/85] Skipping NOV.N (incomplete data coverage)
#
# [28/85] Loading T.N... (already cleaned)
#   Loaded: 4,688,762 rows
#
# [29/85] Loading LMT.N... (already cleaned)
#   Loaded: 3,254,197 rows
#
# [30/85] Skipping DVN.N (incomplete data coverage)
#
# [31/85] Loading APA.N... (already cleaned)
#   Loaded: 4,711,236 rows
#
# [32/85] Loading COF.N... (already cleaned)
#   Loaded: 4,372,933 rows
#
# [33/85] Loading S.N... (already cleaned)
#   Loaded: 2,511,334 rows
#
# [34/85] Loading SLB.N... (already cleaned)
#   Loaded: 5,160,966 rows
#
# [35/85] Loading F.N... (already cleaned)
#   Loaded: 2,423,891 rows
#
# [36/85] Skipping AA.N (incomplete data coverage)
#
# [37/85] Loading MRK.N... (already cleaned)
#   Loaded: 3,708,359 rows
#
# [38/85] Loading UTX.N... (already cleaned)
#   Loaded: 4,243,681 rows
#
# [39/85] Skipping PM.N (incomplete data coverage)
#
# [40/85] Loading MON.N... (already cleaned)
#   Loaded: 5,705,468 rows
#
# [41/85] Loading GD.N... (already cleaned)
#   Loaded: 2,724,270 rows
#
# [42/85] Loading HON.N... (already cleaned)
#   Loaded: 3,152,293 rows
#
# [43/85] Loading DIS.N... (already cleaned)
#   Loaded: 4,242,852 rows
#
# [44/85] Loading RTN.N... (already cleaned)
#   Loaded: 3,174,178 rows
#
# [45/85] Loading WY.N... (already cleaned)
#   Loaded: 2,192,015 rows
#
# [46/85] Loading EXC.N... (already cleaned)
#   Loaded: 3,514,456 rows
#
# [47/85] Loading ETR.N... (already cleaned)
#   Loaded: 3,561,401 rows
#
# [48/85] Loading NSC.N... (already cleaned)
#   Loaded: 4,069,725 rows
#
# [49/85] Loading WMB.N... (already cleaned)
#   Loaded: 3,105,929 rows
#
# [50/85] Loading FDX.N... (already cleaned)
#   Loaded: 3,188,576 rows
#
# [51/85] Loading HNZ.N... (already cleaned)
#   Loaded: 2,372,404 rows
#
# [52/85] Loading DD.N... (already cleaned)
#   Loaded: 4,125,844 rows
#
# [53/85] Loading NKE.N... (already cleaned)
#   Loaded: 3,610,219 rows
#
# [54/85] Skipping MS.N (incomplete data coverage)
#
# [55/85] Loading COP.N... (already cleaned)
#   Loaded: 5,141,092 rows
#
# [56/85] Loading MCD.N... (already cleaned)
#   Loaded: 4,491,750 rows
#
# [57/85] Loading OXY.N... (already cleaned)
#   Loaded: 5,016,917 rows
#
# [58/85] Loading TXN.N... (already cleaned)
#   Loaded: 3,501,520 rows
#
# [59/85] Loading MET.N... (already cleaned)
#   Loaded: 4,183,122 rows
#
# [60/85] Loading JNJ.N... (already cleaned)
#   Loaded: 4,774,850 rows
#
# [61/85] Loading EMC.N... (already cleaned)
#   Loaded: 2,905,677 rows
#
# [62/85] Loading TGT.N... (already cleaned)
#   Loaded: 3,836,017 rows
#
# [63/85] Loading USB.N... (already cleaned)
#   Loaded: 4,645,443 rows
#
# [64/85] Skipping V.N (incomplete data coverage)
#
# [65/85] Loading BA.N... (already cleaned)
#   Loaded: 3,865,998 rows
#
# [66/85] Loading HPQ.N... (already cleaned)
#   Loaded: 4,453,611 rows
#
# [67/85] Loading WMT.N... (already cleaned)
#   Loaded: 5,510,119 rows
#
# [68/85] Loading LOW.N... (already cleaned)
#   Loaded: 3,828,059 rows
#
# [69/85] Loading C.N... (already cleaned)
#   Loaded: 5,574,102 rows
#
# [70/85] Loading AXP.N... (already cleaned)
#   Loaded: 3,936,697 rows
#
# [71/85] Loading PEP.N... (already cleaned)
#   Loaded: 3,294,766 rows
#
# [72/85] Loading BK.N... (already cleaned)
#   Loaded: 4,172,101 rows
#
# [73/85] Loading JPM.N... (already cleaned)
#   Loaded: 5,958,134 rows
#
# [74/85] Loading BMY.N... (already cleaned)
#   Loaded: 3,173,709 rows
#
# [75/85] Loading CAT.N... (already cleaned)
#   Loaded: 4,030,781 rows
#
# [76/85] Loading MMM.N... (already cleaned)
#   Loaded: 3,815,783 rows
#
# [77/85] Loading GS.N... (already cleaned)
#   Loaded: 6,341,312 rows
#
# [78/85] Skipping MA.N (incomplete data coverage)
#
# [79/85] Loading KO.N... (already cleaned)
#   Loaded: 3,380,388 rows
#
# [80/85] Loading BAC.N... (already cleaned)
#   Loaded: 7,886,127 rows
#
# [81/85] Loading UPS.N... (already cleaned)
#   Loaded: 3,814,900 rows
#
# [82/85] Loading WFC.N... (already cleaned)
#   Loaded: 5,797,305 rows
#
# [83/85] Loading XOM.N... (already cleaned)
#   Loaded: 6,603,289 rows
#
# [84/85] Loading ABT.N... (already cleaned)
#   Loaded: 3,199,868 rows
#
# [85/85] Loading FCX.N... (already cleaned)
#   Loaded: 4,787,899 rows
#
#
# ======================================================================
# PROCESSING COMPLETE
# ======================================================================
# Total assets: 85
#   - Loaded (already cleaned): 78
#   - Processed (newly cleaned): 0
# Output folder: ../../FBD_local_data/Clean_Data_parquet
# Step 2: Creating final panel data with chosen interval
# Excluding 7 assets from panel: ['AA.N', 'DVN.N', 'MA.N', 'MS.N', 'NOV.N', 'PM.N', 'V.N']
# ======================================================================
# CREATING PANEL DATA FROM 78 ASSETS
# With VWAP resampling to 1min intervals
# ======================================================================
#
#   [LMT.N_clean] Resampled: 3,254,197 → 32,450 rows
#   Loaded 10/78 assets...
#   [MO.N_clean] Resampled: 3,538,621 → 32,566 rows
#   Loaded 20/78 assets...
#   [AVP.N_clean] Resampled: 2,210,415 → 32,497 rows
#   Loaded 30/78 assets...
#   [MMM.N_clean] Resampled: 3,815,783 → 32,508 rows
#   Loaded 40/78 assets...
#   [MCD.N_clean] Resampled: 4,491,750 → 32,542 rows
#   Loaded 50/78 assets...
#   [HD.N_clean] Resampled: 4,064,567 → 32,554 rows
#   Loaded 60/78 assets...
#   [BHI.N_clean] Resampled: 3,894,528 → 32,476 rows
#   Loaded 70/78 assets...
#   [BK.N_clean] Resampled: 4,172,101 → 32,528 rows
#   Loaded 78/78 assets...
#
# Concatenating 78 assets...
#
# ======================================================================
# PANEL DATA CREATED
# ======================================================================
# Shape: (2536312, 9)
# Date range: 2008-09-02 13:30:00 to 2008-12-30 21:55:00
# Number of assets: 78
#
# Saving panel data to ../../FBD_local_data/panel_data_1min.parquet...
# Saved 2,536,312 rows to ../../FBD_local_data/panel_data_1min.parquet

# %%
print(f"Panel shape: {panel.shape}")
print(f"\nPanel columns: {panel.columns}")
print(f"\nFirst few rows:")
panel.head()
# Out:
# Panel shape: (2536312, 9)
#
# Panel columns: ['timestamp', 'ticker', 'ask-price', 'ask-volume', 'bid-price', 'bid-volume', 'spread', 'mid-price', 'volume_imbalance']
#
# First few rows:
# shape: (5, 9)
# ┌────────────┬────────┬───────────┬────────────┬───┬────────────┬──────────┬───────────┬───────────┐
# │ timestamp  ┆ ticker ┆ ask-price ┆ ask-volume ┆ … ┆ bid-volume ┆ spread   ┆ mid-price ┆ volume_im │
# │ ---        ┆ ---    ┆ ---       ┆ ---        ┆   ┆ ---        ┆ ---      ┆ ---       ┆ balance   │
# │ datetime[μ ┆ str    ┆ f64       ┆ f64        ┆   ┆ f64        ┆ f64      ┆ f64       ┆ ---       │
# │ s]         ┆        ┆           ┆            ┆   ┆            ┆          ┆           ┆ f64       │
# ╞════════════╪════════╪═══════════╪════════════╪═══╪════════════╪══════════╪═══════════╪═══════════╡
# │ 2008-09-02 ┆ ABT    ┆ 58.537504 ┆ 605.0      ┆ … ┆ 484.0      ┆ 0.228103 ┆ 58.423452 ┆ -0.111111 │
# │ 13:30:00   ┆        ┆           ┆            ┆   ┆            ┆          ┆           ┆           │
# │ 2008-09-02 ┆ ALL    ┆ 45.75773  ┆ 163.0      ┆ … ┆ 67.0       ┆ 0.120118 ┆ 45.697671 ┆ -0.417391 │
# │ 13:30:00   ┆        ┆           ┆            ┆   ┆            ┆          ┆           ┆           │
# │ 2008-09-02 ┆ BAC    ┆ 33.0075   ┆ 13393.0    ┆ … ┆ 8656.0     ┆ 0.052003 ┆ 32.981498 ┆ -0.21484  │
# │ 13:30:00   ┆        ┆           ┆            ┆   ┆            ┆          ┆           ┆           │
# │ 2008-09-02 ┆ BAX    ┆ 68.484787 ┆ 328.0      ┆ … ┆ 153.0      ┆ 0.212368 ┆ 68.378602 ┆ -0.363825 │
# │ 13:30:00   ┆        ┆           ┆            ┆   ┆            ┆          ┆           ┆           │
# │ 2008-09-02 ┆ BK     ┆ 35.3655   ┆ 280.0      ┆ … ┆ 153.0      ┆ 0.063016 ┆ 35.333992 ┆ -0.293303 │
# │ 13:30:00   ┆        ┆           ┆            ┆   ┆            ┆          ┆           ┆           │
# └────────────┴────────┴───────────┴────────────┴───┴────────────┴──────────┴───────────┴───────────┘
