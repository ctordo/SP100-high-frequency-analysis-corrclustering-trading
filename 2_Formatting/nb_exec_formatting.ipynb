# %% [markdown]
# # Phase 2: Formatting and NaN evaluation

# %% [markdown]
# **Phase inputs**
# - `panel_data_1min.parquet`
#
# **Phase outputs**
# - `stock_prices.csv`
# - `stock_returns.csv`
# - `stock_spreads.csv`

# %%
from main_formatting import main_2

main_2(display_figures=True)
# Out:
# ...
# ENTERING PHASE 2: FORMATTING
# ...
#
# 2.1 Loading phase inputs...
#                   timestamp ticker  ask-price  ask-volume  bid-price  \
# 0       2008-09-02 13:30:00    ABT  58.537504       605.0  58.309401
# 1       2008-09-02 13:30:00    ALL  45.757730       163.0  45.637612
# 2       2008-09-02 13:30:00    BAC  33.007500     13393.0  32.955497
# 3       2008-09-02 13:30:00    BAX  68.484787       328.0  68.272418
# 4       2008-09-02 13:30:00     BK  35.365500       280.0  35.302484
# ...                     ...    ...        ...         ...        ...
# 2536307 2008-12-30 21:55:00      T  28.240000      1065.0  28.190000
# 2536308 2008-12-30 21:55:00    WAG  23.960000        53.0  23.940000
# 2536309 2008-12-30 21:55:00    WFC  28.820000         1.0  28.700000
# 2536310 2008-12-30 21:55:00    WMB  14.330000       415.0  14.310000
# 2536311 2008-12-30 21:55:00    XRX   7.730000        63.0   7.710000
#
#          bid-volume    spread  mid-price  volume_imbalance  \
# ...
