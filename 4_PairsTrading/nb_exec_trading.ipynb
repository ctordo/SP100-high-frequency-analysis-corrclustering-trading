# %% [markdown]
# # Phase 4: Trading Strategy implementation

# %% [markdown]
# **Phase inputs**
# - `stock_prices.csv`: DataFrame of asset prices, cleaned
# - `clusters.csv`: DataFrame of clusters
#
# **Phase outputs**
# - No data outputs, only graphical and numerical results

# %%
from main_trading import main_4

main_4(window = 300,
       lambda_in = 3,
       lambda_out = 0.5,
       lambda_emergency = 3,
       patience_max = 120,
       use_SUBDATA = True,
       nb_pairs_cap=10,
       display_figures=True)
# Out:
# ======================================================================
# ENTERING PHASE 4: TRADING STRATEGY IMPELMENTATION
# ======================================================================
#
# 4.1 Loading phase inputs...
#   'stock_prices.csv' loaded as 'df_prices'
#   Random clusters generated. Assets are partitioned in 10 different clusters.
# 4.2 Building DATA master dictionary...
#   use_SUBDATA = True -> Using restricted range (approx. 3 weeks) only
#   Succesfully built DATA dictionary.
#   (Sanity check) Plotting cumulative returns of 5 random assets:
# 4.3 Constructing intra-clusters pairs...
#   Pairs successfully constructed. Number of pairs: 329
# 4.4 Evaluation of 10 pairs...
#   Succesfully initialized empty positions table, shape:(6931, 85)
#   Evaluating pair 1/329: DOW-ETR
#   Evaluating pair 2/329: DOW-MON
#   Evaluating pair 3/329: DOW-WFC
#   Evaluating pair 4/329: DOW-XRX
#   Evaluating pair 5/329: ETR-MON
#   Evaluating pair 6/329: ETR-WFC
#   Evaluating pair 7/329: ETR-XRX
#   Evaluating pair 8/329: MON-WFC
#   Evaluating pair 9/329: MON-XRX
#   Evaluating pair 10/329: WFC-XRX
#   Positions array filled, shape: (6931, 85) (columns allocated for 84 assets, +1 for row-wise sum).
# 4.5 Computing PNL series...
# ======================================================================
# PHASE 4 CORRECTLY TERMINATED
# ======================================================================
